# %% [markdown]
# # Introduction
#
# ## Schema from Exports
#
# Slimming Down the Columns to reduce the memory impact on the computer.
#
# ```python
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12291 entries, 0 to 12290
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              12291 non-null  int64
#  1   index                   12291 non-null  int64
#  2   Cube Name               12291 non-null  object
#  3   Cubecon Type            12291 non-null  object
#  4   cardID                  12291 non-null  object
#  5   addedTmsp               12291 non-null  object
#  6   details_name            12291 non-null  object
#  7   details_full_name       12291 non-null  object
#  8   details_artist          12291 non-null  object
#  9   details_rarity          12291 non-null  object
#  10  details_color_identity  12291 non-null  object
#  11  details_colors          12291 non-null  object
#  12  details_set             12291 non-null  object
#  13  details_released_at     12291 non-null  object
#  14  details_cmc             12291 non-null  int64
#  15  details_parsed_cost     12291 non-null  object
#  16  details_type            12291 non-null  object
#  17  details_elo             12291 non-null  float64
#  18  details_popularity      12291 non-null  float64
#  19  details_cubeCount       12291 non-null  int64
#  20  details_loyalty         268 non-null    object
#  21  details_power           5286 non-null   object
#  22  details_toughness       5286 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 2.2+ MB
# ```
#
# Count of Cards per Cubes:
#
# ```
# # Make a DataFrame of above
# cube_munity = cubes_main_event.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
# cube_munity.to_csv('../Data Files/cards_per_unique_cubes.csv')
# ```
#
# Creating a function to clean up the Data:
#
# ```python
# # Give me the # of Cubes each card (overall card name) is in
# # Then we turn it into a function:
# # Then you move this to after the extraction
#
# def tweak_cubes(cubes_main_event):
#     return (cubes_main_event
#      .assign(details_cmc=cubes_main_event.details_cmc.fillna(0).astype('int8'),
#              is_creature=cubes_main_event.details_type.str.contains('Creature'),
#              is_land = cubes_main_event.details_type.str.contains('Land'),
#              is_pwer = cubes_main_event.details_type.str.contains('Planeswalker'),
#              added_to_cube_on = pd.to_datetime(cubes_main_event.addedTmsp, errors='coerce', unit='ms'),
#              composite_id = cubes_main_event['Cube Name'] + '-' + cubes_main_event['cardID']
#         )
#      .astype({'Cubecon Type': 'category', 'details_cmc': 'int8', 'details_rarity': 'category'})
#      .drop(columns=['Unnamed: 0', 'index'])
# )
#
# cleaned_data = tweak_cubes(cubes_main_event)
# ```
#
# Checking for Values in Added Timestamp:
# ```python
# cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),['added_to_cube_on', 'addedTmsp']]
#
# cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),'added_to_cube_on'] = pd.to_datetime(cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),:]['addedTmsp'])
# cleaned_data['added_to_cube_on'] = pd.to_datetime(cleaned_data['added_to_cube_on'], utc=True)
# cleaned_data['days_until_added_to_cube'] = ((cleaned_data['added_to_cube_on'])-pd.to_datetime(cleaned_data['details_released_at']).dt.tz_convert('UTC')).dt.days
#
# ```

# %%
import numpy as np
import pandas as pd

# %%
pre_accepted_cubes = pd.read_csv('../Data Files/pre_accepted_cubes_extract.csv')
poll_winner_cubes = pd.read_csv('../Data Files/poll_winner_cubes_extract.csv')

# %%
pre_accepted_cubes.info()
poll_winner_cubes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12258 entries, 0 to 12257
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              12258 non-null  int64
#  1   index                   12258 non-null  int64
#  2   Cube Name               12258 non-null  object
#  3   Cubecon Type            12258 non-null  object
#  4   cardID                  12258 non-null  object
#  5   addedTmsp               12258 non-null  object
#  6   details_name            12258 non-null  object
#  7   details_full_name       12258 non-null  object
#  8   details_artist          12258 non-null  object
#  9   details_rarity          12258 non-null  object
#  10  details_color_identity  12258 non-null  object
#  11  details_colors          12258 non-null  object
#  12  details_set             12258 non-null  object
#  13  details_released_at     12258 non-null  object
#  14  details_cmc             12258 non-null  int64
#  15  details_parsed_cost     12258 non-null  object
#  16  details_type            12258 non-null  object
#  17  details_elo             12258 non-null  float64
#  18  details_popularity      12258 non-null  float64
#  19  details_cubeCount       12258 non-null  int64
#  20  details_loyalty         244 non-null    object
#  21  details_power           5314 non-null   object
#  22  details_toughness       5314 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 2.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8320 entries, 0 to 8319
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              8320 non-null   int64
#  1   index                   8320 non-null   int64
#  2   Cube Name               8320 non-null   object
#  3   Cubecon Type            8320 non-null   object
#  4   cardID                  8320 non-null   object
#  5   addedTmsp               8320 non-null   object
#  6   details_name            8320 non-null   object
#  7   details_full_name       8320 non-null   object
#  8   details_artist          8320 non-null   object
#  9   details_rarity          8320 non-null   object
#  10  details_color_identity  8320 non-null   object
#  11  details_colors          8320 non-null   object
#  12  details_set             8320 non-null   object
#  13  details_released_at     8320 non-null   object
#  14  details_cmc             8320 non-null   int64
#  15  details_parsed_cost     8320 non-null   object
#  16  details_type            8320 non-null   object
#  17  details_elo             8320 non-null   float64
#  18  details_popularity      8320 non-null   float64
#  19  details_cubeCount       8320 non-null   int64
#  20  details_loyalty         164 non-null    object
#  21  details_power           4066 non-null   object
#  22  details_toughness       4066 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 1.5+ MB

# %%
cubes_main_event = pd.concat([pre_accepted_cubes, poll_winner_cubes], ignore_index=True)
cubes_main_event.head()
# Out:
#    Unnamed: 0  index     Cube Name  Cubecon Type  \
# 0           0      0  Regular Cube  Pre-Accepted
# 1           1      1  Regular Cube  Pre-Accepted
# 2           2      2  Regular Cube  Pre-Accepted
# 3           3      3  Regular Cube  Pre-Accepted
# 4           4      4  Regular Cube  Pre-Accepted
#
#                                  cardID      addedTmsp     details_name  \
# 0  251015ed-9408-4941-894a-158551ed2613  1572901810806  Favored Hoplite
# 1  70e3a90c-1e5c-4646-b3d5-ff46d3fa7b35  1572901810808  Trusted Pegasus
# 2  27394079-924a-4fdb-8be2-f853193eca80  1572901810808   Whitemane Lion
# 3  c47ba1fa-3ace-488b-97e6-d9f3b389c602  1572901810809     Emeria Angel
# 4  2c7142a8-38fa-4e9d-9085-a26fb217a433  1572901810810    Oblivion Ring
#
#            details_full_name                 details_artist details_rarity  \
# 0   Favored Hoplite [ths-13]                  Winona Nelson       uncommon
# 1  Trusted Pegasus [m20-314]                     Chris Rahn         common
# 2    Whitemane Lion [a25-39]  Zoltan Boros & Gabor Szikszai         common
# 3      Emeria Angel [ima-20]                     Jim Murray           rare
# 4     Oblivion Ring [ddg-34]                   Chuck Lukacs         common
#
#    ... details_released_at details_cmc details_parsed_cost  \
# 0  ...          2013-09-27           1               ['w']
# 1  ...          2019-07-12           3          ['w', '2']
# 2  ...          2018-03-16           2          ['w', '1']
# 3  ...          2017-11-17           4     ['w', 'w', '2']
# 4  ...          2011-04-01           3          ['w', '2']
#
#                details_type  details_elo details_popularity details_cubeCount  \
# 0  Creature — Human Soldier       1231.6           1.605022              2388
# 1        Creature — Pegasus       1188.6           1.501516              2234
# 2            Creature — Cat       1175.3           3.695987              5499
# 3          Creature — Angel       1198.9           4.237043              6304
# 4               Enchantment       1274.7          17.211644             25608
#
#    details_loyalty  details_power  details_toughness
# 0              NaN              1                  2
# 1              NaN              2                  2
# 2              NaN              2                  2
# 3              NaN              3                  3
# 4              NaN            NaN                NaN
#
# [5 rows x 23 columns]

# %%
# Update Date when Ran
cubes_main_event.to_csv('../Data Files/cubecon_card_list_2023_09_14.csv')

# %%
# Give me the # of Cubes each card (overall card name) is in
# Then we turn it into a function:
# Then you move this to after the extraction

def tweak_cubes(cubes_main_event):
    return (cubes_main_event
     .assign(details_cmc=cubes_main_event.details_cmc.fillna(0).astype('int8'),
             is_creature=cubes_main_event.details_type.str.contains('Creature'),
             is_land = cubes_main_event.details_type.str.contains('Land'),
             is_planeswalker = cubes_main_event.details_type.str.contains('Planeswalker'),
             is_gold = cubes_main_event.details_colors.str.contains(','),
             added_to_cube_on = pd.to_datetime(cubes_main_event.addedTmsp, errors='coerce', unit='ms'),
             composite_id = cubes_main_event['Cube Name'] + '-' + cubes_main_event['cardID']
        )
     .astype(
         {'Cubecon Type': 'category', 
          'details_cmc': 'int8',
          'details_rarity': 'category', 
          'details_released_at':'datetime64[ns, UTC]'}
     )
     .drop(columns=['Unnamed: 0', 'index'])
)

cleaned_data = tweak_cubes(cubes_main_event)

# %%
cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),'added_to_cube_on'] = pd.to_datetime(cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),:]['addedTmsp'])
cleaned_data['added_to_cube_on'] = pd.to_datetime(cleaned_data['added_to_cube_on'], utc=True)
cleaned_data['days_until_added_to_cube'] = ((cleaned_data['added_to_cube_on'])-pd.to_datetime(cleaned_data['details_released_at']).dt.tz_convert('UTC')).dt.days

# %%
cleaned_data.info()
cubes_main_event.to_csv('../Data Files/cubecon_card_list_2023_09_14.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20578 entries, 0 to 20577
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Cube Name                 20578 non-null  object
#  1   Cubecon Type              20578 non-null  category
#  2   cardID                    20578 non-null  object
#  3   addedTmsp                 20578 non-null  object
#  4   details_name              20578 non-null  object
#  5   details_full_name         20578 non-null  object
#  6   details_artist            20578 non-null  object
#  7   details_rarity            20578 non-null  category
#  8   details_color_identity    20578 non-null  object
#  9   details_colors            20578 non-null  object
#  10  details_set               20578 non-null  object
#  11  details_released_at       20578 non-null  datetime64[ns, UTC]
#  12  details_cmc               20578 non-null  int8
#  13  details_parsed_cost       20578 non-null  object
#  14  details_type              20578 non-null  object
#  15  details_elo               20578 non-null  float64
#  16  details_popularity        20578 non-null  float64
#  17  details_cubeCount         20578 non-null  int64
#  18  details_loyalty           410 non-null    object
#  19  details_power             9373 non-null   object
#  20  details_toughness         9373 non-null   object
#  21  is_creature               20578 non-null  bool
#  22  is_land                   20578 non-null  bool
#  23  is_planeswalker           20578 non-null  bool
#  24  is_gold                   20578 non-null  bool
#  25  added_to_cube_on          20578 non-null  datetime64[ns, UTC]
#  26  composite_id              20578 non-null  object
#  27  days_until_added_to_cube  20578 non-null  int64
# dtypes: bool(4), category(2), datetime64[ns, UTC](2), float64(2), int64(2), int8(1), object(15)
# memory usage: 3.4+ MB

# %%
avg_cubing = (cleaned_data
                 .groupby('Cube Name')
                 .mean()
                 .sort_values('details_popularity', ascending=False)
                 .loc[:,['details_cmc', 'details_popularity', 'is_land', 'is_gold']]
)

avg_cubing
# Out:
#                                   details_cmc  details_popularity   is_land  \
# Cube Name
# Data Generated Vintage Cube          2.427778           10.981196  0.150000
# The Museum of Modern                 1.935417           10.002896  0.235417
# The Bun Magic Cube                   1.697222            9.672429  0.225000
# Dekkaru Cube                         2.585185            8.866795  0.159259
# The Modern Darlings Cube             1.977778            8.805367  0.208333
# Eleusis                              2.342222            8.483045  0.146667
# The Chicago Cube                     2.297222            7.696703  0.144444
# Derek’s Cube                         2.133333            7.679800  0.210417
# The Creative Cube                    2.238961            7.446302  0.207792
# All-Foil Midrange Cube               2.927778            7.050990  0.138889
# 2007 Nostalgia Cube                  2.555556            6.986471  0.166667
# Tiny Leaders                         1.756250            6.743477  0.162500
# Uber Bear's Horror Cube              2.227778            6.501721  0.161111
# Sammich's Peasant Cube               2.586667            6.229512  0.104444
# Emma Partlow's Peasant Cube          2.611111            6.204956  0.111111
# Spooky Black Halloween Graveyard     2.628889            6.156153  0.115556
# The Jund Cube                        2.265928            6.038635  0.141274
# Rainbow Synergy Cube                 2.483370            5.976960  0.181818
# Old Border Foil Cube                 2.778393            5.705660  0.138504
# Turbo Cube                           2.406250            5.696915  0.139423
# Commander extravaganza!              2.422000            5.688056  0.152000
# The Cascade Cube                     2.811111            5.614149  0.138889
# A Study in Harmony                   2.290741            5.609171  0.153704
# The Live the Dream Cube              3.540741            5.443836  0.118519
# Premodern Plus Cube                  2.552778            5.441846  0.141667
# The Tempo Cube                       1.711111            5.354182  0.157407
# Uber Bear's Artifact Cube            2.527778            5.191905  0.127778
# Changeling Cube                      2.002564            5.018386  0.148718
# Tolsimir Cube                        2.689583            4.982185  0.102083
# The Buildaround Cube                 2.517778            4.927345  0.108889
# Regular Cube                         2.108407            4.762873  0.139381
# Petty Nobility                       2.522222            4.604800  0.120000
# Pulp Nouveau                         2.061364            3.807986  0.245455
# Khans Expanded Cube                  2.919192            3.737518  0.131313
# The Penrose Cube                     2.219444            3.723865  0.127778
# Creatureless Cube                    2.393333            3.502088  0.166667
# The Spikeless Cube                   2.577778            3.224485  0.124074
# Loial's Micro Cube                   2.443750            2.955130  0.125000
# Dragons of Winter's Night            1.768519            2.938634  0.347222
# StormTime                            2.548148            2.882831  0.114815
# The Devoid Cube                      2.602667            2.822887  0.213333
# Ravnica Cube                         3.418519            2.769070  0.101852
# May's Fae Cube                       2.605556            2.446860  0.125000
# The Boat Cube                        3.017778            2.389452  0.097778
# Reading Rainbow                      3.208333            2.283807  0.097222
# Counters of Monte Cristo             2.337037            2.134671  0.111111
# Amonkar Desert                       1.945833            2.007860  0.322917
# Vehicle Cube: Eiganjo Drift          2.477778            1.418632  0.066667
#
#                                    is_gold
# Cube Name
# Data Generated Vintage Cube       0.088889
# The Museum of Modern              0.210417
# The Bun Magic Cube                0.097222
# Dekkaru Cube                      0.092593
# The Modern Darlings Cube          0.122222
# Eleusis                           0.057778
# The Chicago Cube                  0.105556
# Derek’s Cube                      0.164583
# The Creative Cube                 0.085714
# All-Foil Midrange Cube            0.191667
# 2007 Nostalgia Cube               0.058333
# Tiny Leaders                      0.150000
# Uber Bear's Horror Cube           0.097222
# Sammich's Peasant Cube            0.104444
# Emma Partlow's Peasant Cube       0.155556
# Spooky Black Halloween Graveyard  0.102222
# The Jund Cube                     0.168975
# Rainbow Synergy Cube              0.376940
# Old Border Foil Cube              0.080332
# Turbo Cube                        0.043269
# Commander extravaganza!           0.108000
# The Cascade Cube                  0.080556
# A Study in Harmony                0.090741
# The Live the Dream Cube           0.237037
# Premodern Plus Cube               0.058333
# The Tempo Cube                    0.124074
# Uber Bear's Artifact Cube         0.030556
# Changeling Cube                   0.097436
# Tolsimir Cube                     0.102083
# The Buildaround Cube              0.122222
# Regular Cube                      0.132743
# Petty Nobility                    0.071111
# Pulp Nouveau                      0.181818
# Khans Expanded Cube               0.200000
# The Penrose Cube                  0.063889
# Creatureless Cube                 0.111111
# The Spikeless Cube                0.100000
# Loial's Micro Cube                0.075000
# Dragons of Winter's Night         0.076389
# StormTime                         0.107407
# The Devoid Cube                   0.002667
# Ravnica Cube                      0.833333
# May's Fae Cube                    0.083333
# The Boat Cube                     0.111111
# Reading Rainbow                   0.902778
# Counters of Monte Cristo          0.116667
# Amonkar Desert                    0.070833
# Vehicle Cube: Eiganjo Drift       0.100000

# %%
x = cleaned_data.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
x.to_csv('../Data Files/top_cards_2023_09_14.csv')
x.head(40)
# Out:
# details_name
# Temple Garden              31
# Stomping Ground            31
# Overgrown Tomb             30
# Sacred Foundry             30
# Blood Crypt                30
# Breeding Pool              29
# Godless Shrine             29
# Steam Vents                29
# Hallowed Fountain          29
# Watery Grave               29
# Lightning Bolt             26
# Windswept Heath            26
# Bloodstained Mire          26
# Wooded Foothills           26
# Path to Exile              26
# Verdant Catacombs          25
# Polluted Delta             25
# Flooded Strand             25
# Arid Mesa                  24
# Misty Rainforest           24
# Marsh Flats                24
# Scalding Tarn              24
# Eternal Witness            23
# Abrade                     23
# Faithless Looting          23
# Duress                     23
# Thraben Inspector          23
# Young Pyromancer           22
# Dismember                  21
# Grim Lavamancer            21
# Carrion Feeder             21
# Tireless Tracker           21
# Brainstorm                 21
# Preordain                  21
# Dragon's Rage Channeler    20
# Hangarback Walker          20
# Fatal Push                 20
# Snapcaster Mage            20
# Frantic Search             20
# Consider                   20
# Name: Cube Name, dtype: int64

# %%
peasant = cleaned_data[cleaned_data['details_rarity'].isin(['uncommon', 'common'])]

# %%
peasant_groupby = peasant.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
peasant_groupby.to_csv('../Data Files/peasant_cards_grouping_2023_09_08.csv')

# %%
cleaned_data[cleaned_data['details_set'] == 'woe'].groupby('Cube Name')['details_name'].nunique().sort_values(ascending=False)
# Out:
# Cube Name
# May's Fae Cube                      39
# The Creative Cube                   27
# The Spikeless Cube                  22
# Amonkar Desert                      17
# Rainbow Synergy Cube                16
# Creatureless Cube                   16
# Tiny Leaders                        16
# The Tempo Cube                      14
# The Jund Cube                       13
# The Buildaround Cube                13
# Spooky Black Halloween Graveyard    13
# A Study in Harmony                  13
# StormTime                           12
# The Live the Dream Cube              8
# The Chicago Cube                     8
# The Cascade Cube                     8
# The Penrose Cube                     7
# The Bun Magic Cube                   7
# Sammich's Peasant Cube               6
# Regular Cube                         5
# Dragons of Winter's Night            5
# Derek’s Cube                         5
# Uber Bear's Artifact Cube            4
# The Devoid Cube                      4
# Counters of Monte Cristo             4
# Changeling Cube                      4
# Turbo Cube                           4
# All-Foil Midrange Cube               4
# Loial's Micro Cube                   3
# Emma Partlow's Peasant Cube          3
# Pulp Nouveau                         1
# Khans Expanded Cube                  1
# Commander extravaganza!              1
# Vehicle Cube: Eiganjo Drift          1
# Name: details_name, dtype: int64

# %%
cleaned_data[cleaned_data['details_name'] == 'Karakas'].groupby('Cube Name')['details_name'].nunique().sort_values(ascending=False)
# Out:
# Cube Name
# Tolsimir Cube                  1
# Data Generated Vintage Cube    1
# Name: details_name, dtype: int64

# %%
cleaned_data[cleaned_data['details_set'] == 'woe'].groupby('Cube Name')['details_name'].nunique().sort_values(ascending=False)
# Out:
# Cube Name
# May's Fae Cube                      39
# The Spikeless Cube                  21
# Amonkar Desert                      17
# Creatureless Cube                   15
# Spooky Black Halloween Graveyard    13
# StormTime                           12
# A Study in Harmony                  12
# The Jund Cube                       12
# The Tempo Cube                      12
# The Cascade Cube                     8
# The Penrose Cube                     7
# Sammich's Peasant Cube               6
# The Chicago Cube                     5
# Counters of Monte Cristo             5
# Changeling Cube                      5
# Dragons of Winter's Night            5
# The Devoid Cube                      4
# Derek’s Cube                         4
# Uber Bear's Artifact Cube            3
# Emma Partlow's Peasant Cube          2
# Loial's Micro Cube                   2
# Commander extravaganza!              1
# Khans Expanded Cube                  1
# Vehicle Cube: Eiganjo Drift          1
# Name: details_name, dtype: int64

# %%
top_cards = cleaned_data.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)

# %%
cleaned_data[cleaned_data['details_set'] == 'woe'].groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
# Out:
# details_name
# Tough Cookie                  11
# Syr Ginger, the Meal Ender     9
# Questing Druid                 8
# Restless Cottage               6
# Mosswood Dreadknight           6
#                               ..
# The Princess Takes Flight      1
# Feed the Cauldron              1
# Witch's Mark                   1
# Experimental Confectioner      1
# Monstrous Rage                 1
# Name: Cube Name, Length: 135, dtype: int64

# %%
woe=cleaned_data[cleaned_data['details_set'] == 'woe'].groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)

# %%
woe.to_clipboard(sep=',')
