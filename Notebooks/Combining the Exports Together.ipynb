# %% [markdown]
# # Introduction
#
# ## Schema from Exports
#
# Slimming Down the Columns to reduce the memory impact on the computer.
#
# ```python
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12291 entries, 0 to 12290
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              12291 non-null  int64
#  1   index                   12291 non-null  int64
#  2   Cube Name               12291 non-null  object
#  3   Cubecon Type            12291 non-null  object
#  4   cardID                  12291 non-null  object
#  5   addedTmsp               12291 non-null  object
#  6   details_name            12291 non-null  object
#  7   details_full_name       12291 non-null  object
#  8   details_artist          12291 non-null  object
#  9   details_rarity          12291 non-null  object
#  10  details_color_identity  12291 non-null  object
#  11  details_colors          12291 non-null  object
#  12  details_set             12291 non-null  object
#  13  details_released_at     12291 non-null  object
#  14  details_cmc             12291 non-null  int64
#  15  details_parsed_cost     12291 non-null  object
#  16  details_type            12291 non-null  object
#  17  details_elo             12291 non-null  float64
#  18  details_popularity      12291 non-null  float64
#  19  details_cubeCount       12291 non-null  int64
#  20  details_loyalty         268 non-null    object
#  21  details_power           5286 non-null   object
#  22  details_toughness       5286 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 2.2+ MB
# ```
#
# Count of Cards per Cubes:
#
# ```
# # Make a DataFrame of above
# cube_munity = cubes_main_event.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
# cube_munity.to_csv('../Data Files/cards_per_unique_cubes.csv')
# ```
#
# Creating a function to clean up the Data:
#
# ```python
# # Give me the # of Cubes each card (overall card name) is in
# # Then we turn it into a function:
# # Then you move this to after the extraction
#
# def tweak_cubes(cubes_main_event):
#     return (cubes_main_event
#      .assign(details_cmc=cubes_main_event.details_cmc.fillna(0).astype('int8'),
#              is_creature=cubes_main_event.details_type.str.contains('Creature'),
#              is_land = cubes_main_event.details_type.str.contains('Land'),
#              is_pwer = cubes_main_event.details_type.str.contains('Planeswalker'),
#              added_to_cube_on = pd.to_datetime(cubes_main_event.addedTmsp, errors='coerce', unit='ms'),
#              composite_id = cubes_main_event['Cube Name'] + '-' + cubes_main_event['cardID']
#         )
#      .astype({'Cubecon Type': 'category', 'details_cmc': 'int8', 'details_rarity': 'category'})
#      .drop(columns=['Unnamed: 0', 'index'])
# )
#
# cleaned_data = tweak_cubes(cubes_main_event)
# ```
#
# Checking for Values in Added Timestamp:
# ```python
# cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),['added_to_cube_on', 'addedTmsp']]
#
# cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),'added_to_cube_on'] = pd.to_datetime(cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),:]['addedTmsp'])
# cleaned_data['added_to_cube_on'] = pd.to_datetime(cleaned_data['added_to_cube_on'], utc=True)
# cleaned_data['days_until_added_to_cube'] = ((cleaned_data['added_to_cube_on'])-pd.to_datetime(cleaned_data['details_released_at']).dt.tz_convert('UTC')).dt.days
#
# ```

# %%
import numpy as np
import pandas as pd

# %%
pre_accepted_cubes = pd.read_csv('../Data Files/pre_accepted_cubes_extract.csv')
poll_winner_cubes = pd.read_csv('../Data Files/poll_winner_cubes_extract.csv')

# %%
pre_accepted_cubes.info()
poll_winner_cubes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12291 entries, 0 to 12290
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              12291 non-null  int64
#  1   index                   12291 non-null  int64
#  2   Cube Name               12291 non-null  object
#  3   Cubecon Type            12291 non-null  object
#  4   cardID                  12291 non-null  object
#  5   addedTmsp               12291 non-null  object
#  6   details_name            12291 non-null  object
#  7   details_full_name       12291 non-null  object
#  8   details_artist          12291 non-null  object
#  9   details_rarity          12291 non-null  object
#  10  details_color_identity  12291 non-null  object
#  11  details_colors          12291 non-null  object
#  12  details_set             12291 non-null  object
#  13  details_released_at     12291 non-null  object
#  14  details_cmc             12291 non-null  int64
#  15  details_parsed_cost     12291 non-null  object
#  16  details_type            12291 non-null  object
#  17  details_elo             12291 non-null  float64
#  18  details_popularity      12291 non-null  float64
#  19  details_cubeCount       12291 non-null  int64
#  20  details_loyalty         268 non-null    object
#  21  details_power           5280 non-null   object
#  22  details_toughness       5280 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 2.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8320 entries, 0 to 8319
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              8320 non-null   int64
#  1   index                   8320 non-null   int64
#  2   Cube Name               8320 non-null   object
#  3   Cubecon Type            8320 non-null   object
#  4   cardID                  8320 non-null   object
#  5   addedTmsp               8320 non-null   object
#  6   details_name            8320 non-null   object
#  7   details_full_name       8320 non-null   object
#  8   details_artist          8320 non-null   object
#  9   details_rarity          8320 non-null   object
#  10  details_color_identity  8320 non-null   object
#  11  details_colors          8320 non-null   object
#  12  details_set             8320 non-null   object
#  13  details_released_at     8320 non-null   object
#  14  details_cmc             8320 non-null   int64
#  15  details_parsed_cost     8320 non-null   object
#  16  details_type            8320 non-null   object
#  17  details_elo             8320 non-null   float64
#  18  details_popularity      8320 non-null   float64
#  19  details_cubeCount       8320 non-null   int64
#  20  details_loyalty         170 non-null    object
#  21  details_power           4079 non-null   object
#  22  details_toughness       4079 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 1.5+ MB

# %%
cubes_main_event = pd.concat([pre_accepted_cubes, poll_winner_cubes], ignore_index=True)
cubes_main_event.head()
# Out:
#    Unnamed: 0  index     Cube Name  Cubecon Type  \
# 0           0      0  Regular Cube  Pre-Accepted
# 1           1      1  Regular Cube  Pre-Accepted
# 2           2      2  Regular Cube  Pre-Accepted
# 3           3      3  Regular Cube  Pre-Accepted
# 4           4      4  Regular Cube  Pre-Accepted
#
#                                  cardID      addedTmsp       details_name  \
# 0  251015ed-9408-4941-894a-158551ed2613  1572901810806    Favored Hoplite
# 1  70e3a90c-1e5c-4646-b3d5-ff46d3fa7b35  1572901810808    Trusted Pegasus
# 2  27394079-924a-4fdb-8be2-f853193eca80  1572901810808     Whitemane Lion
# 3  b958bcdd-d0ea-4ae0-9dd0-e6de5cf74128  1572901810809  Restoration Angel
# 4  c47ba1fa-3ace-488b-97e6-d9f3b389c602  1572901810809       Emeria Angel
#
#             details_full_name                 details_artist details_rarity  \
# 0    Favored Hoplite [ths-13]                  Winona Nelson       uncommon
# 1   Trusted Pegasus [m20-314]                     Chris Rahn         common
# 2     Whitemane Lion [a25-39]  Zoltan Boros & Gabor Szikszai         common
# 3  Restoration Angel [mm3-20]                  Johannes Voss           rare
# 4       Emeria Angel [ima-20]                     Jim Murray           rare
#
#    ... details_released_at details_cmc details_parsed_cost  \
# 0  ...          2013-09-27           1               ['w']
# 1  ...          2019-07-12           3          ['w', '2']
# 2  ...          2018-03-16           2          ['w', '1']
# 3  ...          2017-03-17           4          ['w', '3']
# 4  ...          2017-11-17           4     ['w', 'w', '2']
#
#                details_type  details_elo details_popularity details_cubeCount  \
# 0  Creature — Human Soldier       1226.2           1.630827              2282
# 1        Creature — Pegasus       1155.3           1.550786              2170
# 2            Creature — Cat       1200.3           3.741898              5236
# 3          Creature — Angel       1297.8          18.047724             25254
# 4          Creature — Angel       1253.7           4.351493              6089
#
#    details_loyalty  details_power  details_toughness
# 0              NaN              1                  2
# 1              NaN              2                  2
# 2              NaN              2                  2
# 3              NaN              3                  4
# 4              NaN              3                  3
#
# [5 rows x 23 columns]

# %%
# Update Date when Ran
cubes_main_event.to_csv('../Data Files/cubecon_card_list_2023_06_13.csv')

# %%
# Give me the # of Cubes each card (overall card name) is in
# Then we turn it into a function:
# Then you move this to after the extraction

def tweak_cubes(cubes_main_event):
    return (cubes_main_event
     .assign(details_cmc=cubes_main_event.details_cmc.fillna(0).astype('int8'),
             is_creature=cubes_main_event.details_type.str.contains('Creature'),
             is_land = cubes_main_event.details_type.str.contains('Land'),
             is_planeswalker = cubes_main_event.details_type.str.contains('Planeswalker'),
             is_gold = cubes_main_event.details_colors.str.contains(','),
             added_to_cube_on = pd.to_datetime(cubes_main_event.addedTmsp, errors='coerce', unit='ms'),
             composite_id = cubes_main_event['Cube Name'] + '-' + cubes_main_event['cardID']
        )
     .astype(
         {'Cubecon Type': 'category', 
          'details_cmc': 'int8',
          'details_rarity': 'category', 
          'details_released_at':'datetime64[ns, UTC]'}
     )
     .drop(columns=['Unnamed: 0', 'index'])
)

cleaned_data = tweak_cubes(cubes_main_event)

# %%
cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),'added_to_cube_on'] = pd.to_datetime(cleaned_data.loc[cleaned_data['added_to_cube_on'].isnull(),:]['addedTmsp'])
cleaned_data['added_to_cube_on'] = pd.to_datetime(cleaned_data['added_to_cube_on'], utc=True)
cleaned_data['days_until_added_to_cube'] = ((cleaned_data['added_to_cube_on'])-pd.to_datetime(cleaned_data['details_released_at']).dt.tz_convert('UTC')).dt.days

# %%
cleaned_data.info()
##cubes_main_event.to_csv('../Data Files/cubecon_card_list_2023_06_08.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20611 entries, 0 to 20610
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Cube Name                 20611 non-null  object
#  1   Cubecon Type              20611 non-null  category
#  2   cardID                    20611 non-null  object
#  3   addedTmsp                 20611 non-null  object
#  4   details_name              20611 non-null  object
#  5   details_full_name         20611 non-null  object
#  6   details_artist            20611 non-null  object
#  7   details_rarity            20611 non-null  category
#  8   details_color_identity    20611 non-null  object
#  9   details_colors            20611 non-null  object
#  10  details_set               20611 non-null  object
#  11  details_released_at       20611 non-null  datetime64[ns, UTC]
#  12  details_cmc               20611 non-null  int8
#  13  details_parsed_cost       20611 non-null  object
#  14  details_type              20611 non-null  object
#  15  details_elo               20611 non-null  float64
#  16  details_popularity        20611 non-null  float64
#  17  details_cubeCount         20611 non-null  int64
#  18  details_loyalty           438 non-null    object
#  19  details_power             9359 non-null   object
#  20  details_toughness         9359 non-null   object
#  21  is_creature               20611 non-null  bool
#  22  is_land                   20611 non-null  bool
#  23  is_planeswalker           20611 non-null  bool
#  24  is_gold                   20611 non-null  bool
#  25  added_to_cube_on          20611 non-null  datetime64[ns, UTC]
#  26  composite_id              20611 non-null  object
#  27  days_until_added_to_cube  20611 non-null  int64
# dtypes: bool(4), category(2), datetime64[ns, UTC](2), float64(2), int64(2), int8(1), object(15)
# memory usage: 3.4+ MB

# %%
avg_cubing = (cleaned_data
                 .groupby('Cube Name')
                 .mean()
                 .sort_values('details_popularity', ascending=False)
                 .loc[:,['details_popularity', 'is_land', 'is_gold']]
)

avg_cubing
# Out:
#                                   details_popularity   is_land   is_gold
# Cube Name
# Data Generated Vintage Cube                10.975211  0.155556  0.080556
# The Museum of Modern                       10.066587  0.235417  0.212500
# The Bun Magic Cube                          9.982378  0.216667  0.097222
# Dekkaru Cube                                9.228532  0.151852  0.085185
# The Modern Darlings Cube                    8.802486  0.208333  0.116667
# Eleusis                                     8.563567  0.146667  0.057778
# The Chicago Cube                            8.171992  0.138889  0.108333
# Derek’s Cube                                7.907902  0.206250  0.187500
# The Creative Cube                           7.741129  0.182500  0.105000
# Tiny Leaders                                7.224855  0.189189  0.147609
# All-Foil Midrange Cube                      7.092252  0.138889  0.186111
# 2007 Nostalgia Cube                         6.995210  0.161111  0.058333
# Uber Bear's Horror Cube                     6.606370  0.163889  0.097222
# Sammich's Peasant Cube                      6.536929  0.115556  0.106667
# Spooky Black Halloween Graveyard            6.420121  0.102222  0.104444
# The Jund Cube                               6.412350  0.141274  0.188366
# Emma Partlow's Peasant Cube                 6.236849  0.111111  0.155556
# Rainbow Synergy Cube                        6.186596  0.181818  0.390244
# Turbo Cube                                  5.868828  0.139423  0.043269
# Commander extravaganza!                     5.855447  0.150000  0.104000
# Old Border Foil Cube                        5.813558  0.138504  0.080332
# A Study in Harmony                          5.794140  0.155556  0.092593
# The Live the Dream Cube                     5.647911  0.118519  0.235185
# The Cascade Cube                            5.594145  0.136111  0.080556
# Premodern Plus Cube                         5.502604  0.141667  0.058333
# Uber Bear's Artifact Cube                   5.315829  0.130556  0.030556
# The Tempo Cube                              5.203250  0.138889  0.129630
# Regular Cube                                5.161159  0.142222  0.140000
# Tolsimir Cube                               5.128092  0.093750  0.095833
# The Buildaround Cube                        5.105258  0.118421  0.131579
# Changeling Cube                             4.792898  0.151282  0.115385
# Petty Nobility                              4.649779  0.120000  0.071111
# The Penrose Cube                            4.149880  0.133333  0.066667
# Pulp Nouveau                                3.790429  0.240618  0.196468
# Khans Expanded Cube                         3.786580  0.131313  0.200000
# Loial's Micro Cube                          3.543194  0.125000  0.075000
# The Spikeless Cube                          3.527368  0.122222  0.111111
# Creatureless Cube                           3.235218  0.162222  0.102222
# StormTime                                   3.173940  0.114815  0.114815
# Dragons of Winter's Night                   3.148169  0.354167  0.064815
# May's Fae Cube                              3.086325  0.122222  0.083333
# The Devoid Cube                             2.951983  0.213333  0.002667
# Ravnica Cube                                2.818423  0.101852  0.833333
# The Boat Cube                               2.424947  0.095556  0.106667
# Reading Rainbow                             2.379508  0.091667  0.908333
# Counters of Monte Cristo                    2.252894  0.083333  0.118519
# Amonkar Desert                              2.004713  0.322917  0.070833
# Vehicle Cube: Eiganjo Drift                 1.432961  0.066667  0.100000

# %%
cleaned_data.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False).head(20)
# Out:
# details_name
# Stomping Ground      31
# Temple Garden        31
# Overgrown Tomb       30
# Blood Crypt          30
# Sacred Foundry       30
# Watery Grave         29
# Hallowed Fountain    29
# Godless Shrine       29
# Breeding Pool        29
# Steam Vents          29
# Lightning Bolt       27
# Faithless Looting    26
# Bloodstained Mire    25
# Windswept Heath      25
# Wooded Foothills     25
# Path to Exile        25
# Flooded Strand       24
# Polluted Delta       24
# Duress               24
# Young Pyromancer     24
# Name: Cube Name, dtype: int64

# %%
peasant = cleaned_data[cleaned_data['details_rarity'].isin(['uncommon', 'common'])]

# %%
peasant.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False)
#
# Out:
# details_name
# Faithless Looting         25
# Duress                    22
# Abrade                    22
# Unearth                   21
# Lightning Bolt            21
#                           ..
# Hotshot Mechanic           1
# House Guildmage            1
# Howl of the Night Pack     1
# Howling Giant              1
# Lucid Dreams               1
# Name: Cube Name, Length: 3942, dtype: int64
