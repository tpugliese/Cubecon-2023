# %% [markdown]
# # Introduction
#
# ## Next Steps
#
# URL Of the OG List: https://docs.google.com/spreadsheets/d/1Mch2d3KO2Hc1n4KBpHbNVPtqnWBQ5RX6KeRCq4eOKac/edit#gid=1499993616
#
# ## The Beautiful For Loop I have too much Pride in:
#
# ```python
#
# for row in cube_slice.iterrows():
#         if rq.get(cube_slice['URL'][index]).ok == True:
#             df = pd.json_normalize(rq.get(cube_slice['URL'][index]).json().get('cards').get('mainboard'), sep='_')
#             df['ID'] = cube_slice['ID'][index]
#             df['Cube Name'] = cube_slice['Cube Name'][index]
#             df['Cubecon Type'] = 'Pre-Accepted'
#             df_list.append(df)
#             index+=1
#         else:
#             print('Error Encountered At Index:', index)
#             index+=1
# ```
#
# This is where the magic happens.
#
# We start by iterating for each *row* in our Cube Export.  We want each URL that we've created to generate a JSON response _only for that row_.  This is where we call our `[index]` value because you need to capture the specific row related to each field.
#
# However, before we begin, we don't want our Loop to get broken by a failed HTTP Request for information, so we call the `req.get().ok` parameter to ensure that we _start_ with a `200` response aka `True` before beginning.
#
# We start by calling our URL related to our Index, and returning the HTTP Response of the get into JSON for parsing.  This mostly works because of the `http://cubecobra.com/cube/api/cubeJSON/` API call that returns the _entire_ webpage into JSON format.  Of the response, we're only interested in the `{cards:}` portion, and of those, the `{'mainboard':}` for analysis puroses.  However, because the response is in nested JSON, we need to flatten it because there exist really important attributes in the subsection of `{details:}` for future analysis.  Then the object is turned into a Pandas DataFrame we call "df".
#
# However, if we just stopped there, we would lose a level of attribution when all of the DataFrames are joined together.  Currently the Cube-Level information is outside of the `{mainboard:}` attribute so we instead continue to leverage the `[index]` parameter by adding the "Cube Name" and "Cube ID" to the DataFrame, as well as noting the Type of Cube it is within the larger voting sphere of cubes.
#
# Then the DataFrame is appended to our "df_list" and the index is increased for the next row.  If our response initially encountered a bad HTTP Request, then we print an Error Message and increase the Index so we can continue.

# %%
import pandas as pd
import numpy as np
import requests as rq

# %%
# Import The Cube List
cube_export = pd.read_csv('/Users/tpug/Jupyter Work/Magic The Gathering Projects/Cubecon_2023/Cubecon-2023/Data Files/Copy of CubeCon 2023 Public Voting Dates - Pre-Accepted.csv')

# %%
cube_export.head()
# Out:
#           Cube Name and Link          Discord Twitter Link      Twitter  \
# 0               Regular Cube     Anthony#1172     ahmattox     ahmattox
# 1                 Turbo Cube     Anthony#1172     ahmattox     ahmattox
# 2          Creatureless Cube       beeks#2291  rolltotweet  rolltotweet
# 3  Dragons of Winter's Night   Chill MtG#5975   ChillMtGTV   ChillMtGTV
# 4                    Eleusis  CulticCube#6756   CulticCube   CulticCube
#
#             Pronouns                  Cube Name  \
# 0  he/him, they/them               Regular Cube
# 1  he/him, they/them                 Turbo Cube
# 2          they/them          Creatureless Cube
# 3             he/him  Dragons of Winter's Night
# 4             he/him                    Eleusis
#
#                                                 URL
# 0       https://cubecobra.com/cube/overview/regular
# 1         https://cubecobra.com/cube/overview/turbo
# 2  https://cubecobra.com/cube/overview/no-creatures
# 3          https://cubecobra.com/cube/overview/down
# 4    https://cubecobra.com/cube/overview/culticcube

# %%
# Split URL Into ID, Expand into Fields
# From there, Give me only the "5th" column
# Add to DataFrame as the "ID" Field
cube_export['ID']=cube_export['URL'].str.split('/',expand=True,n=5).loc[:,5]
cube_export.head(30)
# Out:
#              Cube Name and Link               Discord     Twitter Link  \
# 0                  Regular Cube          Anthony#1172         ahmattox
# 1                    Turbo Cube          Anthony#1172         ahmattox
# 2             Creatureless Cube            beeks#2291      rolltotweet
# 3     Dragons of Winter's Night        Chill MtG#5975       ChillMtGTV
# 4                       Eleusis       CulticCube#6756       CulticCube
# 5                Petty Nobility       CulticCube#6756       CulticCube
# 6                  Dekkaru Cube          DEKKARU#2784       GwenDekker
# 7                  Tiny Leaders          DEKKARU#2784       GwenDekker
# 8   Emma Partlow's Peasant Cube      EmmaPartlow#0071     emmadpartlow
# 9          Old Border Foil Cube       GLHF Games#0204       glhf_games
# 10              The Devoid Cube          isticle#5067    worklifevalue
# 11      Commander extravaganza!            Jibux#8904      GagnepainJb
# 12            The Creative Cube            kModz#0889       kModzCubes
# 13  Data Generated Vintage Cube      l0gr1thm1k #8994              NaN
# 14                 Pulp Nouveau     landofMordor#8188   parkerlamascus
# 15      The Live the Dream Cube           Linuka#1130        J_Beleren
# 16               Amonkar Desert      Luckylooter#1175  GoblinGathering
# 17         The Museum of Modern      Luckylooter#1175  GoblinGathering
# 18                 Derek’s Cube      Magicalhack#2262       DGallenMTG
# 19          Premodern Plus Cube     MichaelJheup#6092  CloudgoatRanger
# 20                    StormTime        mjgrenier#2664     matt_grenier
# 21               May's Fae Cube          myagic #5701          myagic1
# 22         Rainbow Synergy Cube        OnTheWind#1023      AetherVjorn
# 23          Khans Expanded Cube       raffsputin#5003      raff_sputin
# 24         The Buildaround Cube        ryancsaxe#0252           rcsaxe
# 25                The Jund Cube             tpug#9728         tylerpug
# 26      Uber Bear's Horror Cube        Uber Bear#4234   UberCubeMTGPod
# 27             The Cascade Cube  Zarash (He/Him)#7550       improphilo
#
#             Twitter            Pronouns                    Cube Name  \
# 0          ahmattox   he/him, they/them                 Regular Cube
# 1          ahmattox   he/him, they/them                   Turbo Cube
# 2       rolltotweet           they/them            Creatureless Cube
# 3        ChillMtGTV              he/him    Dragons of Winter's Night
# 4        CulticCube              he/him                      Eleusis
# 5        CulticCube              he/him               Petty Nobility
# 6        GwenDekker              he/him                 Dekkaru Cube
# 7        GwenDekker              he/him                 Tiny Leaders
# 8      emmadpartlow  she/her, they/them  Emma Partlow's Peasant Cube
# 9        glhf_games              he/him         Old Border Foil Cube
# 10    worklifevalue              he/him              The Devoid Cube
# 11      GagnepainJb              he/him      Commander extravaganza!
# 12       kModzCubes              he/him            The Creative Cube
# 13              NaN              he/him  Data Generated Vintage Cube
# 14   parkerlamascus              he/him                 Pulp Nouveau
# 15        J_Beleren              he/him      The Live the Dream Cube
# 16  GoblinGathering              he/him               Amonkar Desert
# 17  GoblinGathering              he/him         The Museum of Modern
# 18       DGallenMTG              he/him                 Derek’s Cube
# 19  CloudgoatRanger              he/him          Premodern Plus Cube
# 20     matt_grenier              he/him                    StormTime
# 21          myagic1             she/her               May's Fae Cube
# 22      AetherVjorn           they/them         Rainbow Synergy Cube
# 23      raff_sputin              he/him          Khans Expanded Cube
# 24           rcsaxe              he/him         The Buildaround Cube
# 25         tylerpug              he/him                The Jund Cube
# 26   UberCubeMTGPod              he/him      Uber Bear's Horror Cube
# 27       improphilo              he/him             The Cascade Cube
#
#                                                   URL                      ID
# 0         https://cubecobra.com/cube/overview/regular                 regular
# 1           https://cubecobra.com/cube/overview/turbo                   turbo
# 2    https://cubecobra.com/cube/overview/no-creatures            no-creatures
# 3            https://cubecobra.com/cube/overview/down                    down
# 4      https://cubecobra.com/cube/overview/culticcube              culticcube
# 5   https://cubecobra.com/cube/overview/pettynobility           pettynobility
# 6                     https://cubecobra.com/c/dekkaru                    None
# 7     https://cubecobra.com/cube/overview/tinyleaders             tinyleaders
# 8   https://cubecobra.com/cube/list/emma-peasant-c...  emma-peasant-cube-2022
# 9                 https://cubecobra.com/cube/list/obf                     obf
# 10         https://cubecobra.com/cube/overview/devoid                  devoid
# 11       https://cubecobra.com/cube/list/extravaganza            extravaganza
# 12  https://cubecobra.com/cube/overview/creativecu...         creativecubecon
# 13           https://cubecobra.com/cube/overview/data                    data
# 14        https://cubecobra.com/cube/list/pulpnouveau             pulpnouveau
# 15   https://cubecobra.com/cube/overview/LiveTheDream            LiveTheDream
# 16  https://cubecobra.com/cube/overview/amonkardesert           amonkardesert
# 17   https://cubecobra.com/cube/overview/ModernMuseum            ModernMuseum
# 18          https://cubecobra.com/cube/overview/derek                   derek
# 19           https://cubecobra.com/cube/overview/3hcz                    3hcz
# 20          https://cubecobra.com/cube/list/StormTime               StormTime
# 21      https://cubecobra.com/cube/overview/fairytale               fairytale
# 22           https://cubecobra.com/cube/overview/rsc5                    rsc5
# 23                https://cubecobra.com/cube/list/22e                     22e
# 24        https://cubecobra.com/cube/list/buildaround             buildaround
# 25    https://cubecobra.com/cube/overview/jund-em-out             jund-em-out
# 26            https://cubecobra.com/cube/overview/dzp                     dzp
# 27    https://cubecobra.com/cube/overview/cascadecube             cascadecube

# %%
cube_slice = cube_export.loc[:, ['Cube Name', 'ID']]
# Manually Replacing wrong IDs for the Iteration
cube_slice.loc[6, ['ID']] = ['dekkaru']
cube_slice.loc[26, ['ID']] = ['UBHC']
cube_slice.loc[8, ['ID']] = ['emma-peasant-cube-2023']

cube_slice['URL'] = 'http://cubecobra.com/cube/api/cubeJSON/' + cube_slice['ID']
cube_slice['URL']
# Out:
# 0        http://cubecobra.com/cube/api/cubeJSON/regular
# 1          http://cubecobra.com/cube/api/cubeJSON/turbo
# 2     http://cubecobra.com/cube/api/cubeJSON/no-crea...
# 3           http://cubecobra.com/cube/api/cubeJSON/down
# 4     http://cubecobra.com/cube/api/cubeJSON/culticcube
# 5     http://cubecobra.com/cube/api/cubeJSON/pettyno...
# 6        http://cubecobra.com/cube/api/cubeJSON/dekkaru
# 7     http://cubecobra.com/cube/api/cubeJSON/tinylea...
# 8     http://cubecobra.com/cube/api/cubeJSON/emma-pe...
# 9            http://cubecobra.com/cube/api/cubeJSON/obf
# 10        http://cubecobra.com/cube/api/cubeJSON/devoid
# 11    http://cubecobra.com/cube/api/cubeJSON/extrava...
# 12    http://cubecobra.com/cube/api/cubeJSON/creativ...
# 13          http://cubecobra.com/cube/api/cubeJSON/data
# 14    http://cubecobra.com/cube/api/cubeJSON/pulpnou...
# 15    http://cubecobra.com/cube/api/cubeJSON/LiveThe...
# 16    http://cubecobra.com/cube/api/cubeJSON/amonkar...
# 17    http://cubecobra.com/cube/api/cubeJSON/ModernM...
# 18         http://cubecobra.com/cube/api/cubeJSON/derek
# 19          http://cubecobra.com/cube/api/cubeJSON/3hcz
# 20     http://cubecobra.com/cube/api/cubeJSON/StormTime
# 21     http://cubecobra.com/cube/api/cubeJSON/fairytale
# 22          http://cubecobra.com/cube/api/cubeJSON/rsc5
# 23           http://cubecobra.com/cube/api/cubeJSON/22e
# 24    http://cubecobra.com/cube/api/cubeJSON/buildar...
# 25    http://cubecobra.com/cube/api/cubeJSON/jund-em...
# 26          http://cubecobra.com/cube/api/cubeJSON/UBHC
# 27    http://cubecobra.com/cube/api/cubeJSON/cascade...
# Name: URL, dtype: object

# %%
# Start with an Index of 0
index = 0

# Start with an Empty List, the most functional of Data Types
df_list = []

for row in cube_slice.iterrows():
        if rq.get(cube_slice['URL'][index]).ok == True:
            df = pd.json_normalize(rq.get(cube_slice['URL'][index]).json().get('cards').get('mainboard'), sep='_')
            df['ID'] = cube_slice['ID'][index]
            df['Cube Name'] = cube_slice['Cube Name'][index]
            df['Cubecon Type'] = 'Pre-Accepted'
            df_list.append(df)
            index+=1
        else:
            print('Error Encountered At Index:', index)
            index+=1

# %%
pre_accepted_db = pd.concat(df_list)
pre_accepted_db.groupby(['Cube Name']).count()
# Out:
#                              cmc  colorCategory  finish  isUnlimited  rarity  \
# Cube Name
# Amonkar Desert               387              0     387          387      11
# Commander extravaganza!      429              6     434          429       0
# Creatureless Cube            220              0     282          220     179
# Data Generated Vintage Cube  293             16     353          293       0
# Dekkaru Cube                 480              0     479          479       0
# Derek’s Cube                 267             26     471          256       0
# Dragons of Winter's Night    348              0     356          348       0
# Eleusis                      450              3     450          450       0
# Emma Partlow's Peasant Cube  420              0     420          420       0
# Khans Expanded Cube          473              0     473            0       0
# May's Fae Cube               279              3     282          279       0
# Old Border Foil Cube         322              6     334          322       0
# Petty Nobility               450              0     450          450       0
# Premodern Plus Cube          357              0     357          357       0
# Pulp Nouveau                   0             24       0            0       0
# Rainbow Synergy Cube         414             12     414          414       0
# Regular Cube                 409             15     409          409       0
# StormTime                    472              0     472          472       0
# The Buildaround Cube         269             27     269          269       0
# The Cascade Cube             317              5     336          317       0
# The Creative Cube            250             21     315          247       4
# The Devoid Cube              352              7     373          352       0
# The Jund Cube                242             27     341          242       0
# The Live the Dream Cube      463             26     463          463       0
# The Museum of Modern         171              0     171            0       0
# Tiny Leaders                  62              0      69            0       0
# Turbo Cube                   406             20     406          406       0
# Uber Bear's Horror Cube      326             26     354          326       0
#
#                              status  tags  type_line  colors  cardID  ...  \
# Cube Name                                                             ...
# Amonkar Desert                  480   387        387     397     480  ...
# Commander extravaganza!         500   429        429     429     500  ...
# Creatureless Cube               450   270        220     185     450  ...
# Data Generated Vintage Cube     360   294        293     295     360  ...
# Dekkaru Cube                    517   479        479     479     517  ...
# Derek’s Cube                    480   257        260     268     480  ...
# Dragons of Winter's Night       432   351        348     348     432  ...
# Eleusis                         450   450        450     450     450  ...
# Emma Partlow's Peasant Cube     450   420        420     420     450  ...
# Khans Expanded Cube             495   473        473     476     495  ...
# May's Fae Cube                  360   297        279     280     360  ...
# Old Border Foil Cube            361   325        322     322     361  ...
# Petty Nobility                  450   450        450     450     450  ...
# Premodern Plus Cube             360   357        357     357     360  ...
# Pulp Nouveau                    440     2          0      10     440  ...
# Rainbow Synergy Cube            451   414        414     414     451  ...
# Regular Cube                    451   409        409     409     451  ...
# StormTime                       540   472        472     472     540  ...
# The Buildaround Cube            450   306        269     279     450  ...
# The Cascade Cube                360   335        318     317     360  ...
# The Creative Cube               400   247        247     261     400  ...
# The Devoid Cube                 375   352        352     352     375  ...
# The Jund Cube                   361   250        242     250     361  ...
# The Live the Dream Cube         540   463        463     467     540  ...
# The Museum of Modern            480   171        171     173     480  ...
# Tiny Leaders                    476   124         60      69     476  ...
# Turbo Cube                      416   406        406     406     416  ...
# Uber Bear's Horror Cube         360   326        326     326     360  ...
#
#                              details_colorcategory  details_tokens  \
# Cube Name
# Amonkar Desert                                 480              93
# Commander extravaganza!                        500              89
# Creatureless Cube                              450             114
# Data Generated Vintage Cube                    360              50
# Dekkaru Cube                                   517              71
# Derek’s Cube                                   480              82
# Dragons of Winter's Night                      432              34
# Eleusis                                        450              81
# Emma Partlow's Peasant Cube                    450              68
# Khans Expanded Cube                            495              45
# May's Fae Cube                                 360              39
# Old Border Foil Cube                           361              22
# Petty Nobility                                 450              86
# Premodern Plus Cube                            360              19
# Pulp Nouveau                                   440              53
# Rainbow Synergy Cube                           451              94
# Regular Cube                                   451              55
# StormTime                                      540              90
# The Buildaround Cube                           450              70
# The Cascade Cube                               360              41
# The Creative Cube                              400             103
# The Devoid Cube                                375              45
# The Jund Cube                                  361              77
# The Live the Dream Cube                        540             132
# The Museum of Modern                           480              42
# Tiny Leaders                                   476              89
# Turbo Cube                                     416              49
# Uber Bear's Horror Cube                        360              53
#
#                              details_loyalty   ID  Cubecon Type  \
# Cube Name
# Amonkar Desert                             1  480           480
# Commander extravaganza!                    7  500           500
# Creatureless Cube                         14  450           450
# Data Generated Vintage Cube               23  360           360
# Dekkaru Cube                               9  517           517
# Derek’s Cube                              18  480           480
# Dragons of Winter's Night                  0  432           432
# Eleusis                                   31  450           450
# Emma Partlow's Peasant Cube                4  450           450
# Khans Expanded Cube                        0  495           495
# May's Fae Cube                             0  360           360
# Old Border Foil Cube                       0  361           361
# Petty Nobility                             0  450           450
# Premodern Plus Cube                        0  360           360
# Pulp Nouveau                               5  440           440
# Rainbow Synergy Cube                       0  451           451
# Regular Cube                               4  451           451
# StormTime                                  0  540           540
# The Buildaround Cube                       7  450           450
# The Cascade Cube                          12  360           360
# The Creative Cube                         15  400           400
# The Devoid Cube                            4  375           375
# The Jund Cube                             11  361           361
# The Live the Dream Cube                   44  540           540
# The Museum of Modern                      15  480           480
# Tiny Leaders                              21  476           476
# Turbo Cube                                 6  416           416
# Uber Bear's Horror Cube                    8  360           360
#
#                              details_image_flip  imgUrl  imgBackUrl  notes  \
# Cube Name
# Amonkar Desert                               14       0           0      0
# Commander extravaganza!                       6       0           0      0
# Creatureless Cube                            22       0           0    179
# Data Generated Vintage Cube                   3      22           0     21
# Dekkaru Cube                                  0     150           0     26
# Derek’s Cube                                 13       0           0      0
# Dragons of Winter's Night                    15       2           0      4
# Eleusis                                      19       0           0      0
# Emma Partlow's Peasant Cube                  12       0           0      0
# Khans Expanded Cube                           5       0           0      0
# May's Fae Cube                                1       0           0     11
# Old Border Foil Cube                          0       0           0      0
# Petty Nobility                               32       0           0      0
# Premodern Plus Cube                           0       0           0      0
# Pulp Nouveau                                  3       0           0      0
# Rainbow Synergy Cube                         21       0           0      0
# Regular Cube                                  0       0           0      0
# StormTime                                     2       0           0      0
# The Buildaround Cube                          7       0           0      0
# The Cascade Cube                             16       0           0      0
# The Creative Cube                             9     196           4      1
# The Devoid Cube                               2       2           0      0
# The Jund Cube                                18       0           0      1
# The Live the Dream Cube                      22       0           0      0
# The Museum of Modern                          7       0           0      0
# Tiny Leaders                                 17       0           0     49
# Turbo Cube                                    4       0           0      0
# Uber Bear's Horror Cube                      47       0           0      0
#
#                              markedForDelete
# Cube Name
# Amonkar Desert                             6
# Commander extravaganza!                   75
# Creatureless Cube                        311
# Data Generated Vintage Cube              130
# Dekkaru Cube                              28
# Derek’s Cube                              48
# Dragons of Winter's Night                 30
# Eleusis                                    0
# Emma Partlow's Peasant Cube                0
# Khans Expanded Cube                        1
# May's Fae Cube                            15
# Old Border Foil Cube                       5
# Petty Nobility                             0
# Premodern Plus Cube                       11
# Pulp Nouveau                              26
# Rainbow Synergy Cube                       0
# Regular Cube                               0
# StormTime                                  2
# The Buildaround Cube                      33
# The Cascade Cube                          34
# The Creative Cube                        318
# The Devoid Cube                           16
# The Jund Cube                            221
# The Live the Dream Cube                    6
# The Museum of Modern                      71
# Tiny Leaders                             415
# Turbo Cube                                 0
# Uber Bear's Horror Cube                   52
#
# [28 rows x 76 columns]

# %%
# Initial Fields as of 6/3/23
extract = pre_accepted_db.loc[:,[
      'index'
    , 'Cube Name'
    , 'Cubecon Type'
    , 'cardID'
    , 'addedTmsp'
    , 'details_name'
    , 'details_full_name'
    , 'details_artist'
    , 'details_rarity'
    , 'details_color_identity'
    , 'details_colors'
    , 'details_set'
    , 'details_released_at'
    , 'details_cmc'
    , 'details_parsed_cost'
    , 'details_type'
    , 'details_elo'
    , 'details_popularity'
    , 'details_cubeCount'
    , 'details_loyalty'
    , 'details_power'
    , 'details_toughness'
]]

# %%
extract.to_csv('../Data Files/pre_accepted_cubes_extract.csv', encoding='utf-8')

# %%
# Beneath Here Tests the Data

test_data = cube_slice.loc[0:3]

# %%
# request_1 = rq.get(test_data['URL'][0]).json().get('cards').get('mainboard')
# Create a DataFrame that's a Normalized JSON View of a Request from the URL Parameter of test_data's [0]th Value
# Which is turned into JSON, and give me the 'Cards' Subset, and the 'Mainboard'
# Also Separate the Normalized fields with '_'
df_1 = pd.json_normalize(rq.get(test_data['URL'][0]).json().get('cards').get('mainboard'), sep='_')
df_1['ID'] = test_data['ID'][0]
df_1['Cube Name'] = test_data['Cube Name'][0]
df_1['Cubecon Type'] = 'Pre-Accepted'
df_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-fb886ba130b1> in <module>
#       3 # Which is turned into JSON, and give me the 'Cards' Subset, and the 'Mainboard'
#       4 # Also Separate the Normalized fields with '_'
# ----> 5 df_1 = pd.json_normalize(rq.get(test_data['URL'][0]).json().get('cards').get('mainboard'), sep='_')
#       6 df_1['ID'] = test_data['ID'][0]
#       7 df_1['Cube Name'] = test_data['Cube Name'][0]
#
# NameError: name 'test_data' is not defined
