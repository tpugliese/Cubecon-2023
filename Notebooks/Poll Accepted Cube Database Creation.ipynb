# %% [markdown]
# # Introduction
#
# ## As a pair for Pre-Accepted Cube Database
#
# This is a list of all of the cubes that were put into twitter polls.

# %%
import numpy as np
import pandas as pd
import requests as rq

# %%
poll_cubes = pd.read_csv('/Users/tpug/Jupyter Work/Magic The Gathering Projects/Cubecon_2023/Cubecon-2023/Data Files/cubecon_polled_cubes.csv')

# %%
poll_cubes[poll_cubes['Poll Winner']==True]
# Out:
#                   Cube Name and Link Result  Poll Winner     Twitter Link  \
# 0                2007 Nostalgia Cube      ✅         True  MachineSchoolin
# 3                 A Study in Harmony      ✅         True     matt_grenier
# 4             All-Foil Midrange Cube      ✅         True      killagreg17
# 6                    Changeling Cube      ✅         True        MimTeyers
# 11          Counters of Monte Cristo      ✅         True              NaN
# 25                Loial's Micro Cube      ✅         True        candellum
# 38                      Ravnica Cube      ✅         True              NaN
# 39                   Reading Rainbow      ✅         True   CmndrCrrspndnt
# 40            Sammich's Peasant Cube      ✅         True      Sammich_mtg
# 43  Spooky Black Halloween Graveyard      ✅         True        zrdavis19
# 45                     The Boat Cube      ✅         True  PaulAPe82906479
# 47                The Bun Magic Cube      ✅         True    luckypapermtg
# 48                  The Chicago Cube      ✅         True              NaN
# 55          The Modern Darlings Cube      ✅         True       jaaaaabs21
# 60                  The Penrose Cube      ✅         True       dvdsndvdsn
# 63                The Spikeless Cube      ✅         True              NaN
# 65                    The Tempo Cube      ✅         True      turnergregs
# 70                     Tolsimir Cube      ✅         True              NaN
# 72         Uber Bear's Artifact Cube      ✅         True   UberCubeMTGPod
# 76       Vehicle Cube: Eiganjo Drift      ✅         True  GoblinGathering
#
#             Twitter           Pronouns                         Cube Name  \
# 0   MachineSchoolin          they/them               2007 Nostalgia Cube
# 3      matt_grenier             he/him                A Study in Harmony
# 4       killagreg17             he/him            All-Foil Midrange Cube
# 6         MimTeyers             he/him                   Changeling Cube
# 11              NaN             he/him          Counters of Monte Cristo
# 25        candellum             he/him                Loial's Micro Cube
# 38              NaN             he/him                      Ravnica Cube
# 39   CmndrCrrspndnt             he/him                   Reading Rainbow
# 40      Sammich_mtg             he/him            Sammich's Peasant Cube
# 43        zrdavis19  he/him, they/them  Spooky Black Halloween Graveyard
# 45  PaulAPe82906479             he/him                     The Boat Cube
# 47    luckypapermtg             he/him                The Bun Magic Cube
# 48              NaN             he/him                  The Chicago Cube
# 55       jaaaaabs21             he/him          The Modern Darlings Cube
# 60       dvdsndvdsn             he/him                  The Penrose Cube
# 63              NaN             he/him                The Spikeless Cube
# 65      turnergregs             he/him                    The Tempo Cube
# 70              NaN             he/him                     Tolsimir Cube
# 72   UberCubeMTGPod             he/him         Uber Bear's Artifact Cube
# 76  GoblinGathering             he/him       Vehicle Cube: Eiganjo Drift
#
#                                                   URL
# 0            https://cubecobra.com/cube/overview/2007
# 3   https://cubecobra.com/cube/overview/HarmonicSt...
# 4   https://cubecobra.com/cube/overview/f5a3647a-6...
# 6          https://cubecobra.com/cube/overview/change
# 11            https://cubecobra.com/cube/blog/plusone
# 25  https://cubecobra.com/cube/overview/5e9ef2d65a...
# 38           https://cubecobra.com/cube/overview/u7so
# 39    https://cubecobra.com/cube/overview/allgoldcube
# 40  https://cubecobra.com/cube/overview/5d3ed83247...
# 43          https://cubecobra.com/cube/overview/3uv2p
# 45           https://cubecobra.com/cube/overview/Boat
# 47    https://cubecobra.com/cube/overview/andymangold
# 48  https://cubecobra.com/cube/overview/TheChicago...
# 55           https://cubecobra.com/cube/overview/tmdc
# 60        https://cubecobra.com/cube/overview/penrose
# 63            https://cubecobra.com/cube/overview/sd4
# 65      https://cubecobra.com/cube/overview/tempocube
# 70       https://cubecobra.com/cube/overview/Tolsimir
# 72  https://cubecobra.com/cube/overview/5ec8208651...
# 76   https://cubecobra.com/cube/overview/eiganjodrift

# %%
# Split the URL for the ID
poll_cubes['ID']=poll_cubes['URL'].str.split('/',expand=True).loc[:,5]
# Remove unnessecary columns
poll_cubes_slice = poll_cubes.loc[:,['Cube Name', 'ID', 'Poll Winner']]

# Placeholder for replacing IDs before URL gets created
# poll_cubes_slice.loc[X, ['ID']] = ['<correct_id>']

# Replace URL with Cubecobra API Request
poll_cubes_slice['URL'] = 'http://cubecobra.com/cube/api/cubeJSON/' + poll_cubes_slice['ID']

# %%
# Check that we have things in the correct order
poll_cubes_slice.head(20)
# Out:
#                       Cube Name                                    ID  \
# 0           2007 Nostalgia Cube                                  2007
# 1                     2cmc Cube                                   9ia
# 2    360 Card Micro Pauper Cube              62b5653883be610fb3f9f5cc
# 3            A Study in Harmony                       HarmonicStudies
# 4        All-Foil Midrange Cube  f5a3647a-66fa-4c0a-941a-35cc3d994f21
# 5             Brawl Boomer Box                                  4wszi
# 6               Changeling Cube                                change
# 7                  Channel Cube                               channel
# 8                   Choice cube                                  7lp6
# 9           College Campus Cube                            viclindsay
# 10                  Combat Cube                                   atk
# 11     Counters of Monte Cristo                               plusone
# 12      Fifteen Card Highlander                                   fus
# 13                   Glory Days                                 2n2tj
# 14      Graveyard Flavored Cube                               dirtcup
# 15           Ian's Peasant Cube                                   rbo
# 16       Ian's Proliferate Cube              63e44d4ef4f93b0f6cd5ea94
# 17                Infinity Cube                              infinity
# 18          Innistrad Set Theme                      InnistradCubeCon
# 19  Ivan_Draw_Go's Peasant Plus                 IvanDrawGoPeasantPlus
#
#     Poll Winner                                                URL
# 0          True        http://cubecobra.com/cube/api/cubeJSON/2007
# 1         False         http://cubecobra.com/cube/api/cubeJSON/9ia
# 2         False  http://cubecobra.com/cube/api/cubeJSON/62b5653...
# 3          True  http://cubecobra.com/cube/api/cubeJSON/Harmoni...
# 4          True  http://cubecobra.com/cube/api/cubeJSON/f5a3647...
# 5         False       http://cubecobra.com/cube/api/cubeJSON/4wszi
# 6          True      http://cubecobra.com/cube/api/cubeJSON/change
# 7         False     http://cubecobra.com/cube/api/cubeJSON/channel
# 8         False        http://cubecobra.com/cube/api/cubeJSON/7lp6
# 9         False  http://cubecobra.com/cube/api/cubeJSON/viclindsay
# 10        False         http://cubecobra.com/cube/api/cubeJSON/atk
# 11         True     http://cubecobra.com/cube/api/cubeJSON/plusone
# 12        False         http://cubecobra.com/cube/api/cubeJSON/fus
# 13        False       http://cubecobra.com/cube/api/cubeJSON/2n2tj
# 14        False     http://cubecobra.com/cube/api/cubeJSON/dirtcup
# 15        False         http://cubecobra.com/cube/api/cubeJSON/rbo
# 16        False  http://cubecobra.com/cube/api/cubeJSON/63e44d4...
# 17        False    http://cubecobra.com/cube/api/cubeJSON/infinity
# 18        False  http://cubecobra.com/cube/api/cubeJSON/Innistr...
# 19        False  http://cubecobra.com/cube/api/cubeJSON/IvanDra...

# %%
# Poll Winners
main_event = poll_cubes_slice[poll_cubes_slice['Poll Winner']==True]
main_event = main_event.reset_index()
# Not Winners, but all Cubes are Winners
side_event = poll_cubes_slice[poll_cubes_slice['Poll Winner']==False]
side_event = side_event.reset_index()

main_event.head(20)
# Out:
#     index                         Cube Name  \
# 0       0               2007 Nostalgia Cube
# 1       3                A Study in Harmony
# 2       4            All-Foil Midrange Cube
# 3       6                   Changeling Cube
# 4      11          Counters of Monte Cristo
# 5      25                Loial's Micro Cube
# 6      38                      Ravnica Cube
# 7      39                   Reading Rainbow
# 8      40            Sammich's Peasant Cube
# 9      43  Spooky Black Halloween Graveyard
# 10     45                     The Boat Cube
# 11     47                The Bun Magic Cube
# 12     48                  The Chicago Cube
# 13     55          The Modern Darlings Cube
# 14     60                  The Penrose Cube
# 15     63                The Spikeless Cube
# 16     65                    The Tempo Cube
# 17     70                     Tolsimir Cube
# 18     72         Uber Bear's Artifact Cube
# 19     76       Vehicle Cube: Eiganjo Drift
#
#                                       ID  Poll Winner  \
# 0                                   2007         True
# 1                        HarmonicStudies         True
# 2   f5a3647a-66fa-4c0a-941a-35cc3d994f21         True
# 3                                 change         True
# 4                                plusone         True
# 5               5e9ef2d65a2e60108646545d         True
# 6                                   u7so         True
# 7                            allgoldcube         True
# 8               5d3ed83247586d63776acbf6         True
# 9                                  3uv2p         True
# 10                                  Boat         True
# 11                           andymangold         True
# 12                        TheChicagoCube         True
# 13                                  tmdc         True
# 14                               penrose         True
# 15                                   sd4         True
# 16                             tempocube         True
# 17                              Tolsimir         True
# 18              5ec82086510bc4414742ec52         True
# 19                          eiganjodrift         True
#
#                                                   URL
# 0         http://cubecobra.com/cube/api/cubeJSON/2007
# 1   http://cubecobra.com/cube/api/cubeJSON/Harmoni...
# 2   http://cubecobra.com/cube/api/cubeJSON/f5a3647...
# 3       http://cubecobra.com/cube/api/cubeJSON/change
# 4      http://cubecobra.com/cube/api/cubeJSON/plusone
# 5   http://cubecobra.com/cube/api/cubeJSON/5e9ef2d...
# 6         http://cubecobra.com/cube/api/cubeJSON/u7so
# 7   http://cubecobra.com/cube/api/cubeJSON/allgold...
# 8   http://cubecobra.com/cube/api/cubeJSON/5d3ed83...
# 9        http://cubecobra.com/cube/api/cubeJSON/3uv2p
# 10        http://cubecobra.com/cube/api/cubeJSON/Boat
# 11  http://cubecobra.com/cube/api/cubeJSON/andyman...
# 12  http://cubecobra.com/cube/api/cubeJSON/TheChic...
# 13        http://cubecobra.com/cube/api/cubeJSON/tmdc
# 14     http://cubecobra.com/cube/api/cubeJSON/penrose
# 15         http://cubecobra.com/cube/api/cubeJSON/sd4
# 16   http://cubecobra.com/cube/api/cubeJSON/tempocube
# 17    http://cubecobra.com/cube/api/cubeJSON/Tolsimir
# 18  http://cubecobra.com/cube/api/cubeJSON/5ec8208...
# 19  http://cubecobra.com/cube/api/cubeJSON/eiganjo...

# %%
# Iterate for the API Pull for Lists

index = 0

df_list = []

for row in main_event.iterrows():
    if rq.get(main_event['URL'][index]).ok == True:
        df = pd.json_normalize(rq.get(main_event['URL'][index]).json().get('cards').get('mainboard'), sep='_')
        df['ID'] = main_event['ID'][index]
        df['Cube Name'] = main_event['Cube Name'][index]
        df['Cubecon Type'] = 'Poll Winner'
        df_list.append(df)
        #print(True)
        index+=1
    else:
        print('Error Encountered At Index:', index)
        index+=1

# %%
cubes_main_event = pd.concat(df_list)
cubes_main_event.groupby(['Cube Name']).count()
# Out:
#                                   cmc  colorCategory  finish  isUnlimited  \
# Cube Name
# 2007 Nostalgia Cube               360             21     360          360
# A Study in Harmony                446              0     446          446
# All-Foil Midrange Cube              0              0       0            0
# Changeling Cube                   343             22     343          343
# Counters of Monte Cristo          487              5     487          487
# Loial's Micro Cube                110              2     110          102
# Ravnica Cube                      540              0     540          540
# Reading Rainbow                   360              0     360          360
# Sammich's Peasant Cube            440              1     450          440
# Spooky Black Halloween Graveyard  321             29     350          319
# The Boat Cube                     432              0     432          432
# The Bun Magic Cube                342             81     354          341
# The Chicago Cube                  279              3     279          279
# The Modern Darlings Cube          333             25     346          333
# The Penrose Cube                  284              1     286          284
# The Spikeless Cube                463             15     471          463
# The Tempo Cube                    520             15     520          520
# Tolsimir Cube                     368              0     368            0
# Uber Bear's Artifact Cube         349              5     354          349
# Vehicle Cube: Eiganjo Drift       344              2     344          344
#
#                                   rarity  status  tags  type_line  colors  \
# Cube Name
# 2007 Nostalgia Cube                    0     360   360        360     360
# A Study in Harmony                     0     540   446        446     454
# All-Foil Midrange Cube                 0     360     0          0       0
# Changeling Cube                        0     390   356        343     344
# Counters of Monte Cristo               1     540   487        487     487
# Loial's Micro Cube                     0     160   110        110     111
# Ravnica Cube                           0     540   540        540     540
# Reading Rainbow                        0     360   360        360     360
# Sammich's Peasant Cube                 0     450   450        440     441
# Spooky Black Halloween Graveyard       0     450   319        319     326
# The Boat Cube                          0     450   432        432     432
# The Bun Magic Cube                     0     360   341        341     342
# The Chicago Cube                       0     360   279        281     281
# The Modern Darlings Cube               0     360   333        333     333
# The Penrose Cube                       0     360   284        284     284
# The Spikeless Cube                     0     540   499        463     464
# The Tempo Cube                         0     540   520        520     520
# Tolsimir Cube                          0     480   450        368     368
# Uber Bear's Artifact Cube              0     360   349        349     350
# Vehicle Cube: Eiganjo Drift            0     360   344        344     345
#
#                                   cardID  ...  details_colorcategory  \
# Cube Name                                 ...
# 2007 Nostalgia Cube                  360  ...                    360
# A Study in Harmony                   540  ...                    540
# All-Foil Midrange Cube               360  ...                    360
# Changeling Cube                      390  ...                    390
# Counters of Monte Cristo             540  ...                    540
# Loial's Micro Cube                   160  ...                    160
# Ravnica Cube                         540  ...                    540
# Reading Rainbow                      360  ...                    360
# Sammich's Peasant Cube               450  ...                    450
# Spooky Black Halloween Graveyard     450  ...                    450
# The Boat Cube                        450  ...                    450
# The Bun Magic Cube                   360  ...                    360
# The Chicago Cube                     360  ...                    360
# The Modern Darlings Cube             360  ...                    360
# The Penrose Cube                     360  ...                    360
# The Spikeless Cube                   540  ...                    540
# The Tempo Cube                       540  ...                    540
# Tolsimir Cube                        480  ...                    480
# Uber Bear's Artifact Cube            360  ...                    360
# Vehicle Cube: Eiganjo Drift          360  ...                    360
#
#                                   details_tokens   ID  Cubecon Type  \
# Cube Name
# 2007 Nostalgia Cube                           22  360           360
# A Study in Harmony                           103  540           540
# All-Foil Midrange Cube                        80  360           360
# Changeling Cube                               64  390           390
# Counters of Monte Cristo                      37  540           540
# Loial's Micro Cube                            44  160           160
# Ravnica Cube                                  49  540           540
# Reading Rainbow                               63  360           360
# Sammich's Peasant Cube                        59  450           450
# Spooky Black Halloween Graveyard              74  450           450
# The Boat Cube                                 62  450           450
# The Bun Magic Cube                            43  360           360
# The Chicago Cube                              82  360           360
# The Modern Darlings Cube                      41  360           360
# The Penrose Cube                               1  360           360
# The Spikeless Cube                           111  540           540
# The Tempo Cube                                60  540           540
# Tolsimir Cube                                110  480           480
# Uber Bear's Artifact Cube                     56  360           360
# Vehicle Cube: Eiganjo Drift                   49  360           360
#
#                                   details_loyalty  details_image_flip  \
# Cube Name
# 2007 Nostalgia Cube                             0                   0
# A Study in Harmony                             21                  30
# All-Foil Midrange Cube                         37                  23
# Changeling Cube                                 2                   0
# Counters of Monte Cristo                        3                   0
# Loial's Micro Cube                              0                   0
# Ravnica Cube                                    8                   0
# Reading Rainbow                                15                   8
# Sammich's Peasant Cube                          2                  12
# Spooky Black Halloween Graveyard                9                  13
# The Boat Cube                                   8                  14
# The Bun Magic Cube                             11                   7
# The Chicago Cube                               10                   9
# The Modern Darlings Cube                       11                   4
# The Penrose Cube                                0                   0
# The Spikeless Cube                              7                  25
# The Tempo Cube                                  0                  33
# Tolsimir Cube                                  24                  15
# Uber Bear's Artifact Cube                       0                   1
# Vehicle Cube: Eiganjo Drift                     3                   6
#
#                                   markedForDelete  imgBackUrl  imgUrl  notes
# Cube Name
# 2007 Nostalgia Cube                             0           0       0      0
# A Study in Harmony                              2           0       0      0
# All-Foil Midrange Cube                          0           0       0      0
# Changeling Cube                                12           0       0      0
# Counters of Monte Cristo                        1           0       0      0
# Loial's Micro Cube                              2           0       0      8
# Ravnica Cube                                    1           0       0      0
# Reading Rainbow                                 0           0       0      0
# Sammich's Peasant Cube                        170           0       0      0
# Spooky Black Halloween Graveyard               52           0       0      0
# The Boat Cube                                   9           0       0      0
# The Bun Magic Cube                             37           0       0      0
# The Chicago Cube                               32           0       0     62
# The Modern Darlings Cube                        3           0       0      0
# The Penrose Cube                                2           0       0      0
# The Spikeless Cube                             34           0       0      0
# The Tempo Cube                                  5           0       0     70
# Tolsimir Cube                                 238           0       0      1
# Uber Bear's Artifact Cube                       6           0       0      0
# Vehicle Cube: Eiganjo Drift                    20           0       0      0
#
# [20 rows x 76 columns]

# %%
# Initial Fields as of 6/3/23:
# Keep Exact same as other Export for Eventual Joining
extract = cubes_main_event.loc[:,[
      'index'
    , 'Cube Name'
    , 'Cubecon Type'
    , 'cardID'
    , 'addedTmsp'
    , 'details_name'
    , 'details_full_name'
    , 'details_artist'
    , 'details_rarity'
    , 'details_color_identity'
    , 'details_colors'
    , 'details_set'
    , 'details_released_at'
    , 'details_cmc'
    , 'details_parsed_cost'
    , 'details_type'
    , 'details_elo'
    , 'details_popularity'
    , 'details_cubeCount'
    , 'details_loyalty'
    , 'details_power'
    , 'details_toughness'
]]

extract.head()
# Out:
#    index            Cube Name Cubecon Type  \
# 0      0  2007 Nostalgia Cube  Poll Winner
# 1      1  2007 Nostalgia Cube  Poll Winner
# 2      2  2007 Nostalgia Cube  Poll Winner
# 3      3  2007 Nostalgia Cube  Poll Winner
# 4      4  2007 Nostalgia Cube  Poll Winner
#
#                                  cardID      addedTmsp       details_name  \
# 0  e5056bca-bd90-4b50-8630-105558f8ef92  1609163513008   Flametongue Kavu
# 1  b96d6e67-f690-4f19-bb25-a7c2d2aaf42f  1609163513008       Spiritmonger
# 2  b7b4e357-de48-4461-8109-bbb07fff5171  1609163513008        Serra Angel
# 3  908a2215-7231-43a4-8fec-5d1e4233c028  1609163513008          Masticore
# 4  49d3b91d-2e4f-4574-89f8-7b804f1d21bf  1609163513008  Forgotten Ancient
#
#              details_full_name details_artist details_rarity  \
# 0    Flametongue Kavu [pls-60]   Pete Venters       uncommon
# 1       Spiritmonger [apc-121]     Glen Angus           rare
# 2         Serra Angel [7ed-42]       Mark Zug           rare
# 3          Masticore [uds-134]  Paolo Parente           rare
# 4  Forgotten Ancient [scg-120]     Mark Tedin           rare
#
#   details_color_identity  ... details_released_at details_cmc  \
# 0                    [R]  ...          2001-02-05           4
# 1                 [B, G]  ...          2001-06-04           5
# 2                    [W]  ...          2001-04-11           5
# 3                     []  ...          1999-06-07           4
# 4                    [G]  ...          2003-05-26           4
#
#   details_parsed_cost                   details_type details_elo  \
# 0              [r, 3]                Creature — Kavu      1395.9
# 1           [g, b, 3]               Creature — Beast      1235.6
# 2           [w, w, 3]               Creature — Angel      1289.1
# 3                 [4]  Artifact Creature — Masticore      1383.3
# 4              [g, 3]           Creature — Elemental      1243.9
#
#   details_popularity  details_cubeCount  details_loyalty  details_power  \
# 0          13.812975              19176              NaN              4
# 1           1.981617               2751              NaN              6
# 2           6.314379               8766              NaN              4
# 3           1.643784               2282              NaN              4
# 4           3.276764               4549              NaN              0
#
#   details_toughness
# 0                 2
# 1                 6
# 2                 4
# 3                 4
# 4                 3
#
# [5 rows x 22 columns]

# %%
extract.to_csv('../Data Files/poll_winner_cubes_extract.csv', encoding='utf-8')
