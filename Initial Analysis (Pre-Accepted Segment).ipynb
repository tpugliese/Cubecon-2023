# %% [markdown]
# # Introduction
#
# ## Pre-Accepted
#
# Slimming Down the Columns to reduce the memory impact on the computer.
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12291 entries, 0 to 12290
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              12291 non-null  int64
#  1   index                   12291 non-null  int64
#  2   Cube Name               12291 non-null  object
#  3   Cubecon Type            12291 non-null  object
#  4   cardID                  12291 non-null  object
#  5   addedTmsp               12291 non-null  object
#  6   details_name            12291 non-null  object
#  7   details_full_name       12291 non-null  object
#  8   details_artist          12291 non-null  object
#  9   details_rarity          12291 non-null  object
#  10  details_color_identity  12291 non-null  object
#  11  details_colors          12291 non-null  object
#  12  details_set             12291 non-null  object
#  13  details_released_at     12291 non-null  object
#  14  details_cmc             12291 non-null  int64
#  15  details_parsed_cost     12291 non-null  object
#  16  details_type            12291 non-null  object
#  17  details_elo             12291 non-null  float64
#  18  details_popularity      12291 non-null  float64
#  19  details_cubeCount       12291 non-null  int64
#  20  details_loyalty         268 non-null    object
#  21  details_power           5286 non-null   object
#  22  details_toughness       5286 non-null   object
# dtypes: float64(2), int64(4), object(17)
# memory usage: 2.2+ MB
# ```

# %%
import numpy as np
import pandas as pd

# %%
cubes = pd.read_csv('/Users/tpug/Jupyter Work/Magic The Gathering Projects/Cubecon_2023/Cubecon-2023/pre_accepted_cubes_extract.csv')

# %%
cubes.sort_values(['details_cubeCount', 'details_name'], ascending=False).groupby('details_name').head()
# Out:
#        Unnamed: 0  index                    Cube Name  Cubecon Type  \
# 1864          116    116                      Eleusis  Pre-Accepted
# 3064          416    416                 Dekkaru Cube  Pre-Accepted
# 3330          142    142                 Tiny Leaders  Pre-Accepted
# 3839          170    170  Emma Partlow's Peasant Cube  Pre-Accepted
# 4223          104    104         Old Border Foil Cube  Pre-Accepted
# ...           ...    ...                          ...           ...
# 11850         279    279      Uber Bear's Horror Cube  Pre-Accepted
# 3563          375    375                 Tiny Leaders  Pre-Accepted
# 8486          418    418                 Derek’s Cube  Pre-Accepted
# 7464          356    356               Amonkar Desert  Pre-Accepted
# 3742           73     73  Emma Partlow's Peasant Cube  Pre-Accepted
#
#                                      cardID      addedTmsp  \
# 1864   d573ef03-4730-45aa-93dd-e45ac1dbaf4a  1584594385839
# 3064   c8c8390f-4072-454f-8dc4-174919187a47  1648821986328
# 3330   677da834-7f4a-4f60-9151-de7ddcf29622  1681609463015
# 3839   1ddc5922-f62a-4f91-809e-f959edfcfc6a  1668800951485
# 4223   6e8b2951-3c66-4042-add9-b2615951ba52  1629660712439
# ...                                     ...            ...
# 11850  51ddebe2-aad6-4097-ac02-fa6c99f30de7  1681776427348
# 3563   8ebd7ce4-550d-41ab-8559-97efb234a0a1  1683296048015
# 8486   263a2fea-e6b6-48f1-bff8-e556dd1daae5  1683593275794
# 7464   ab8976d8-f77d-460f-82fa-d324cbd3d4b5  1683304846480
# 3742   3e3f0bcd-0796-494d-bf51-94b33c1671e9  1668800951467
#
#                details_name               details_full_name  \
# 1864         Lightning Bolt        Lightning Bolt [lea-161]
# 3064         Lightning Bolt        Lightning Bolt [2x2-361]
# 3330         Lightning Bolt        Lightning Bolt [mm2-122]
# 3839         Lightning Bolt        Lightning Bolt [ced-162]
# 4223         Lightning Bolt          Lightning Bolt [jgp-1]
# ...                     ...                             ...
# 11850     Conjurer's Mantle      Conjurer's Mantle [moc-12]
# 3563   Nashi, Moon's Legacy   Nashi, Moon's Legacy [mat-39]
# 8486   Nashi, Moon's Legacy  Nashi, Moon's Legacy [mat-218]
# 7464         Drannith Ruins        Drannith Ruins [mat-100]
# 3742             Propaganda            Propaganda [sld-381]
#
#             details_artist details_rarity  ... details_released_at  \
# 1864      Christopher Rush         common  ...          1993-08-05
# 3064          Chuck Lukacs       uncommon  ...          2022-07-08
# 3330   Christopher Moeller       uncommon  ...          2015-05-22
# 3839      Christopher Rush         common  ...          1993-12-10
# 4223      Christopher Rush           rare  ...          1998-01-01
# ...                    ...            ...  ...                 ...
# 11850          Fiona Hsieh           rare  ...          2023-04-21
# 3563           Patrik Hell           rare  ...          2023-05-12
# 8486               TAPIOCA           rare  ...          2023-05-12
# 7464           Steve Ellis           rare  ...          2023-05-12
# 3742          Scott Balmer           rare  ...          2022-04-22
#
#       details_cmc details_parsed_cost                     details_type  \
# 1864            1               ['r']                          Instant
# 3064            1               ['r']                          Instant
# 3330            1               ['r']                          Instant
# 3839            1               ['r']                          Instant
# 4223            1               ['r']                          Instant
# ...           ...                 ...                              ...
# 11850           2          ['w', '1']             Artifact — Equipment
# 3563            3     ['u', 'g', 'b']  Legendary Creature — Rat Shaman
# 8486            3     ['u', 'g', 'b']  Legendary Creature — Rat Shaman
# 7464            0                ['']                             Land
# 3742            3          ['u', '2']                      Enchantment
#
#        details_elo details_popularity details_cubeCount  details_loyalty  \
# 1864        1539.6          30.964661             42987              NaN
# 3064        1539.6          30.964661             42987              NaN
# 3330        1539.6          30.964661             42987              NaN
# 3839        1539.6          30.964661             42987              NaN
# 4223        1539.6          30.964661             42987              NaN
# ...            ...                ...               ...              ...
# 11850       1210.9           0.043220                60              NaN
# 3563        1216.2           0.036016                50              NaN
# 8486        1216.2           0.036016                50              NaN
# 7464        1253.2           0.016568                23              NaN
# 3742        1200.0           0.000000                 0              NaN
#
#        details_power  details_toughness
# 1864             NaN                NaN
# 3064             NaN                NaN
# 3330             NaN                NaN
# 3839             NaN                NaN
# 4223             NaN                NaN
# ...              ...                ...
# 11850            NaN                NaN
# 3563               3                  4
# 8486               3                  4
# 7464             NaN                NaN
# 3742             NaN                NaN
#
# [10337 rows x 23 columns]

# %%
cube_munity = cubes.groupby('details_name')['Cube Name'].nunique().sort_values(ascending=False) >= 6

# %%
cubes.groupby('details_type')['details_colors'].count()
# Out:
# details_type
# Artifact                               630
# Artifact Creature — Angel               10
# Artifact Creature — Ape                  4
# Artifact Creature — Assembly-Worker      7
# Artifact Creature — Beast               11
#                                       ...
# Tribal Sorcery — Eldrazi                 1
# Tribal Sorcery — Elf                     1
# Tribal Sorcery — Giant                   2
# Tribal Sorcery — Goblin                  1
# World Enchantment                        1
# Name: details_colors, Length: 987, dtype: int64

# %%
cubes.head()
# Out:
#    Unnamed: 0  index     Cube Name  Cubecon Type  \
# 0           0      0  Regular Cube  Pre-Accepted
# 1           1      1  Regular Cube  Pre-Accepted
# 2           2      2  Regular Cube  Pre-Accepted
# 3           3      3  Regular Cube  Pre-Accepted
# 4           4      4  Regular Cube  Pre-Accepted
#
#                                  cardID      addedTmsp       details_name  \
# 0  251015ed-9408-4941-894a-158551ed2613  1572901810806    Favored Hoplite
# 1  70e3a90c-1e5c-4646-b3d5-ff46d3fa7b35  1572901810808    Trusted Pegasus
# 2  27394079-924a-4fdb-8be2-f853193eca80  1572901810808     Whitemane Lion
# 3  b958bcdd-d0ea-4ae0-9dd0-e6de5cf74128  1572901810809  Restoration Angel
# 4  c47ba1fa-3ace-488b-97e6-d9f3b389c602  1572901810809       Emeria Angel
#
#             details_full_name                 details_artist details_rarity  \
# 0    Favored Hoplite [ths-13]                  Winona Nelson       uncommon
# 1   Trusted Pegasus [m20-314]                     Chris Rahn         common
# 2     Whitemane Lion [a25-39]  Zoltan Boros & Gabor Szikszai         common
# 3  Restoration Angel [mm3-20]                  Johannes Voss           rare
# 4       Emeria Angel [ima-20]                     Jim Murray           rare
#
#    ... details_cmc details_parsed_cost              details_type details_elo  \
# 0  ...           1               ['w']  Creature — Human Soldier      1240.8
# 1  ...           3          ['w', '2']        Creature — Pegasus      1156.9
# 2  ...           2          ['w', '1']            Creature — Cat      1148.0
# 3  ...           4          ['w', '3']          Creature — Angel      1366.1
# 4  ...           4     ['w', 'w', '2']          Creature — Angel      1223.7
#
#    details_popularity details_cubeCount details_loyalty  details_power  \
# 0            1.633700              2268             NaN              1
# 1            1.553744              2157             NaN              2
# 2            3.750738              5207             NaN              2
# 3           18.057857             25069             NaN              3
# 4            4.370939              6068             NaN              3
#
#    details_toughness  card_unique_cubes
# 0                  2                NaN
# 1                  2                NaN
# 2                  2                NaN
# 3                  4                NaN
# 4                  3                NaN
#
# [5 rows x 24 columns]

# %%
cube_munity.to_csv('top_360_cards.csv')
